# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #   Session Three

# %% [markdown]
# #### 1.What is miniconda and what is the difference between it and Anaconda?

# %% [markdown]
#  Conda is an open source package management system and environment management system that runs on Windows, macOS and Linux. ... Conda easily creates, saves, loads and switches between environments on your local computer. It was created for Python programs, but it can package and distribute software for any language.
#
# Both Anaconda and Miniconda uses Conda as the package manager. The difference among Anaconda and Miniconda is that Miniconda only comes the package management system. So when you install it, there is just the management system and not coming with a bundle of pre-installed packages like Anaconda does.
#
# Miniconda gives you the Python interpreter itself, along with a command-line tool called conda which operates as a cross-platform package manager geared toward Python packages, similar in spirit to the apt or yum tools that Linux users might be familiar with.
#
# Anaconda includes both Python and conda, and additionally bundles a suite of other pre-installed packages geared toward scientific computing. Because of the size of this bundle, expect the installation to consume several gigabytes of disk space.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2.Not clean code and someone who optimzed it into a clean code

# %% [markdown]
# Clean code is the foundation of a good application that is easy to maintain and extend with new functionalities. Writing clean code requires knowledge, practice, and assertiveness. The principles presented in this article are just a drop in the ocean of clean code rules.

# %% [markdown]
# https://github.com/ryanmcdermott/clean-code-javascript

# %% [markdown]
# #### 3.What is framework? why we use it? advantages and disadvantages?

# %% [markdown]
# A Framework is linked to the word reusable, when the programmer is at work constantly using a certain code.
# It can be set up as a framework to be used if he needs it without having to rebuild it again.
#
# A framework exists to provide a base from which you can build your next project with great success. Providing an architecture, abstraction, and some initial code towards your goals—it can provide a way to save time and strengthen a project throughout every stage of development.
#
# Advantages of Using A Framework:
#
# 1.Simplifies Many Tasks and Challenges For smaller systems, the right framework makes great strides in the number of lines of code engineers are required to write, test, and maintain by hand. A high-quality framework that comes with a lot of functionality and systems pre-build can save weeks of development time and cut down writing thousands of lines of code.
#
# 2.Standardised Coding Practices:  is its ability to create a well-defined structure to follow throughout the lifetime of a project.
#
# 3.Testing and Debugging :Applications built around a more rigid architecture are typically easier to separate out and test individually than those engineered using a custom solution.
#
# Disadvantages of Using A Framework:
#
# 1.Framework Limitations:developers must be certain they are choosing a framework that meets their needs and requirements. Being forced to change and skew a project to fit in later stages can cause as many problems as it solves.
#
# 2.The result of over-reliance on the framework is fewer chances for programmers to solve complex problems and gain a detailed grasp on the entire application.
#
# 3.he bulk of the code included within a large framework may well be irrelevant. This is particularly true when building exceptionally simple web apps. The extra files and unnecessary code in your project can adversely impact the speed and performance of a framework and the sites it supports.

# %% [markdown]
# #### 4.Most popular 5 processors in laptops and 5 in mobiles? and why?

# %% [markdown]
# =>The different types of processors are (microprocessor, microcontroller, embedded processor, digital signal processor and the processors can be varied according to the devices).
#
# =>The important elements of the CPU are labelled as heart elements of the processor and system.
# The control unit activates, fetches, and execute the input instructions.
#
# =>The processor can be embedded in a microprocessor and comprise of unit IC chip.
# But some devices are based on multi-core processors.
# It comprises one or more CPU.It is a typical tiny component with pins embedded on the motherboard.
# It can also be linked to motherboard with fan and heat sink to disperse the produced heat.
#
# //NOT SURE FROM THIS
# =>Most popular 5 processors in laptops:
#   1. Intel Core i9-12900K:: Cores:16 ,Threads: 24
#   2. Intel Core i5-12600K:: Cores:10 ,Threads:16, Base clock:3.7GHz , Boost clock:4.9GHz ,L3 cache: 20MB
#   3. AMD Ryzen 7 5800X3D:: Cores:8 ,Threads:16 ,Base clock:3.7GHz , Boost clock:4.7GHz ,L3 cache: 100MB
#   4. AMD Ryzen 9 5900X:: Cores:12 ,Threads:24 ,Base clock:3.7GHz ,Boost clock:4.8GHz ,L3 cache:64MB
#   5. AMD Ryzen 7 5800X:: Cores:8 ,Threads:16 ,Base clock:3.8GHz ,Boost clock:4.7GHz ,L3 cache: 32MB
#
# => Most popular 5 processors in mobile:
#
#     1.Apple A15 Bionic
#     2.Dimensity 9000
#     3.Snapdragon 8 Gen 1
#     4.Apple A14 Bionic
#     5.Snapdragon 888 Plus

# %% [markdown]
# #### 5.How to make recursive code faster than iterative which don’t support multi-threading?

# %% [markdown]
# The first ,We divide the problem into subproblems.
# The second thing is that the least processor has two threads, main threads, and the other thread. When we need to run something else on it, we can turn it on. It is possible to take advantage of the second thread in the recursion.
# The third thing is the mimosition, which is when the function is run once, we do not run it again because its output has already become with us
# The fourth thing is the tabulation.

# %% [markdown]
# #### 6.what is hashtables ? why we use hash tables in unordered list

# %% [markdown]
# The hashtable is a map, but what is unique about it is that there is a function called the hash function, and it takes the key and gives us the position for it in the memory. This process is called the hashing.
#
# Hashing is a technique used for performing insertions ,deletions,and finds in
# constant avarage time O(1), and this main reason for using the hashmap in the unordered list.

# %% [markdown]
# #### 7.how to print the error type for the user in try catch

# %%
from traceback import print_exc

try : 
    print(ahmed)
except:
    print_exc()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Haneen Ibrahim\AppData\Local\Temp\ipykernel_7060\1399484391.py", line 4, in <cell line: 3>
#     print(ahmed)
# NameError: name 'ahmed' is not defined
