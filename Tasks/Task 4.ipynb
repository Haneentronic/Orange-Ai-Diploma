# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# # Task Four

# %% [markdown]
# #### 1. Why are apple processors better and how could the rest be better?

# %% [markdown]
# 1-Apple Silicon chips are RISC chips, while Intel chips are CISC chips. The comparison is not Apple vs Intel, but RISC vs CISC. “RISC” is “reduced instruction set computing,” and “CISC” is “complex instruction computing.”
#
# CISC chips, such as Intel and AMD, have a large number of instructions, of varying length, and some are rarely used. The CISC chip has the overhead of determining whether it has the entire instruction. CISC chips acquire cruft over the years, which slows them down. Since the instruction set is complicated, the chip is more complex and therefore slower in comparison to an equally powerful RISC chip.
#
# RISC chips, such as Apple Silicon and ARM, have fewer instructions, and all of them have the same length, so there is no overhead in determining whether the chip has the entire instruction. Since the instruction set is simple, the chip is simpler and therefore faster.
#
# RISC chips power the fastest supercomputer in the world, which is in Japan.
#
# 2-Apple does not rely on processor chip manufacturers for its hardware. Instead, it designs processors that conform to its vision of the latest iPhone. By building its own processors, Apple is able to have complete control over the design and performance of products.
#
# 3-Apple processors are also comparatively bigger in size, and this allows it to include additional hardware resources that significantly improve the iPhone’s performance. Additional CPU cores coupled with a bigger performance cache allow the iPhone to outperform and outlast its competitors.
#
# 4- Apple’s M1-series Macs have two kinds of cores: high performance and high efficiency cores. The difference between high performance and efficiency cores is that the efficiency cores are power saving while the performance cores can be used for more demanding tasks. So while the performance cores focus on demanding tasks there won’t be a hit on power efficient processing, both can happen in tandem.
#
# 5-Apple’s A Series CPUs in contrast have been delivering excellent improvements with each generation because Apple has started with a fundamentally superior architecture (ARM, which Apple was the original investor in, owned 20% of and it was Apple that placed ARM on the map)
#
#
# -We can make other processors with the same efficiency or close to the efficiency of Apple processors by increasing the size of the core and adding parts that improve performance and efficiency and also by increasing the number of cores.

# %% [markdown]
# ### 2. The diffrenece between each processor and the charastaristics of them?

# %% [markdown]
# ###### We are going to compare the Intel® Core™ i9-12900K processor with the AMD Ryzen 7 5800X processor
#
# Intel® Core™ i9-12900K: Cores=16 , Performance-cores=8 ,Efficient-cores=8 , Threads=24 ,Max Turbo Frequency=5.20 GHz , Performance-core Base Frequency=3.20 GHz ,Efficient-core Base Frequency=2.40 GHz ,Cache=30 MB,Max.Operating Temperature=100°C ,Memory Types= DDR5
#
# AMD Ryzen™ 7 5800X : Cores=8 ,Threads=16,Base Frequency=3.8GHz ,Max Turbo Frequency=4.7GHz ,Cache=32MB ,Max. Operating Temperature=90°C ,Memory Type=
# DDR4
#
# ########################################################################
#
# cores:The number of cores in the processors.
#
# Threads:The number of threads in processors.
#
# Max Turbo Frequency:The maximum speed that a single core can reach.
#
# Cache: the size of cache memory.
#
# Max.Operating Temperature:The maximum temperature that the processor can reach
#
# i9:Represent the number of cores and Hyper-threads together.
#
# Memory Type:maxemam memory size ,This means that the processor can support up to how many gigabytes of RAM.

# %% [markdown]
# ### 3.What is tabulation and momization?

# %% [markdown]
# Memoization : refers to the technique of caching and reusing previosly computed results.
#
# Tabulation :is similar to memoization but in tabulation we fill the cache iteratively , in tabulation we can not use recursion becuse it use loops.
#
# both using in dynamic programming,dynamic programming is a way to solving a bigger problem when we are going to reuse a solution of smaller or sub Problems.
#
# ex:19 * 20=380
#
# so 19 * 21=result of(19 * 20)+19
#
# ex:we want to git factorial for number 100.
#
# In Tabulation:
#
# int dp[100];
#
# dp[0]=1;
#
# for(int i=0 ;i<100 ; i++){
#
# dp[i]=dp[i-1]*i;
#
# }
#
# In memoization :
#
# int dp[100];
#
# int fact(int n){
#
# if(n==0){
#
# return 1;
#
# }else{
#
#  return dp[n]=fact(n-1)*n;

# %% [markdown]
# ### 4. What is linear probing?

# %% [markdown]
# linear probing: is a Strategy for resolving collisions or keys that map to the same index in a hash table.
#
#  strategy :
#
# 1- use a hash function to find the index for a key
#
# 2-If that spot contains a value , use the next available spot ,if you reach the end of the array , go back to the front.

# %% [markdown]
# ![OneNote%20for%20Windows%2010%209_7_2022%209_12_38%20PM.png](attachment:OneNote%20for%20Windows%2010%209_7_2022%209_12_38%20PM.png)

# %% [markdown]
# ### 5.What is dynamic memory allocation and how to make it?

# %% [markdown]
# Dynamic memory allocation is method to assign memory space during runtime ,like array we do a certain way to make it dynamic.
#
# Static memory allocation  only be done on stack ,but dynamic memory allocation done on stack and heap.
#
# int n ;
#
# cin>>n;
#
# int *arr[]=new int[n] //new dynamic array
#
# delete [] arr; // to delete this array.

# %% [markdown]
# ### 6.All c++ frameworks in all tracks.

# %% [markdown]
# 1- abseil-cpp - Abseil C++ Common Libraries. [Apache2]
#
# 2-Apache C++ Standard Library - STDCXX, A collection of algorithms,
# containers, iterators, and other fundamental components. [retired] [Apache2]
#
# 3-APR - Apache Portable Runtime. Another library of cross-platform utility functions. [Apache2]
#
# 4-ASL - Adobe Source Libraries provides peer-reviewed and portable C++ source libraries. [MIT]
#
# 5-Boost- A large collection of generic C++ libraries. [Boost]
#
# 6-BDE - The BDE Development Environment from Bloomberg Labs. [Apache2]
#
# 7-C++ Workflow - C++ Parallel Computing and Asynchronous Networking Engine. [Apache2]
#
# 8-Cinder - A community-developed, free and open source library for professional-quality creative coding. [BSD]
#
# 9-Coost - A tiny boost library in C++11. [MIT]
#
# 10-Cxxomfort - A small, header-only library that backports various facilities from more recent C++ Standards to C++03 and later. [MIT]
#
# 11-Dlib- A toolkit for making real world machine learning and data analysis applications in C++ [Boost]
#
# 12-EASTL - Electronic Arts Standard Template Library. [BSD]
#
# 13-ETL - Embedded Template Library. [MIT]
#
# 14-fead-cpp - Framework for Enterprise Application Development. [Apache2]
#
# 15-Folly - An open-source C++ library developed and used at Facebook. [Apache2]
#
# 16-FunctionalPlus - Functional Programming Library for C++. Write concise and readable C++ code. [MIT]
#
# 17-GLib - GLib provides the core application building blocks for libraries and applications written in C. [LGPL]
#
# 18-JUCE - An all-encompassing C++ class library for developing cross-platform software. [Core-Module: ISC, Rest: GPL2/GPL3/Commercial]
#
# 19-Kigs framework - A free and open source C++ modular multi-purpose cross platform RAD framework. [MIT]
#
# 20-libPhenom - libPhenom is an eventing framework for building high performance and high scalability systems in C. [Apache2]
#
# 21-LibSourcey - C++11 evented IO for real-time video streaming and high performance networking applications. [LGPL]
#
# 22-LibU - A multiplatform utility library written in C. [BSD]
#
# 23-Loki - A C++ library of designs, containing flexible implementations of common design patterns and idioms. [MIT]
#
# 24-MiLi - Minimal headers-only C++ Library. [Boost]
#
# 25-OpenFrameworks - A cross platform open source toolkit for creative coding in C++. [MIT]
#
# 26-Qt- A cross-platform application and UI framework. [GPL/LGPL/Commercial]
#
# 27-Reason - A cross platform framework designed to bring the ease of use of Java, .Net, or Python to developers who require the performance and strength of C++. [GPL2]
#
# 28-ROOT - A set of OO frameworks with all the functionality needed to handle and analyze large amounts of data in a very efficient way. Used at CERN. [LGPL]
#
# 29-Seastar - An advanced, open-source C++ framework for high-performance server applications on modern hardware. [Apache-2.0 License] seastar.io
#
# 30-STLport - An exemplary version of STL. [Free]
#
# 31-STXXL - Standard Template Library for Extra Large Data Sets. [Boost]
#
# 32-tbox - A glib-like multi-platform c library. [Apache2]
#
# 33-Ultimate++ - A C++ cross-platform rapid application development framework. [BSD]
#
# 34-uSTL - The small STL library. [MIT]
#
# 35-Windows Template Library - A C++ library for developing Windows applications and UI components. [Public]
#
# 36-Yomm2 - Fast, Orthogonal, Open multi-methods. Supersedes Yomm11 [Boost]

# %% [markdown]
# ### 7.What is web services , micro-services and APIs?

# %% [markdown]
# APIs : is a software interface that allows two applications to interact with each other without any user intervention. API is a collection of software functions and procedures. In simple terms, API means a software code that can be accessed or executed. API is defined as a code that helps two different software’s to communicate and exchange data with each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Web Services :is an API but it needs a network to work, is a standardized medium to propagate communication between the client and server applications on the WWW .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Micro service : Before talking about it, we will talk about montolithic, which is an architecture that is done for any application or system, Micro service is a architecturel style to struct my applications as collection of services,It considers each part of the system or application as a separate service or application, independent of the rest of the parts.
#
# How do these parts communicate with each other?
#
# Communicate through channels that are usually HTTP requistes(API)
#
# One of the advantages is that we make each part of the application in a completely different programming language from the other.

# %% [markdown]
# ### 8.how to write a multiple line code with different programming languages in the same program?

# %% [markdown]
# 1-use a framework for interfacing like The Boost Python Library, it is framework  for interfacing Python and C++,It allows you to quickly and seamlessly expose C++ classes functions and objects to Python, and vice-versa, using no special tools - just your C++ compiler.
#
#
# 2-For languages to interact they would need to have some kind of interface or API to connect. In the current web architecture, this typically consists of a microservices which communicate through REST APIs using HTTP.

# %% [markdown]
# ## 9.cronjobs with examples

# %% [markdown]
#  is a utility program that lets users input commands for scheduling tasks repeatedly at a specific time. Tasks scheduled in cron are called cron jobs. Users can determine what kind of task they want to automate and when it should be executed.

# %% [markdown]
# ###### Example cron jobs

# %% [markdown]
# 1. Schedule a job at February 2nd, every year
#
#  0 9 2 2 *   /usr/local/bin/yearly_backup
#
# 2. Schedule a job every hour at the fifth minute, every day
#
#  5 * * * *      $ HOME/bin/daily.job >> $HOME/tmp/out  2>&1
#
# 3. Schedule a job 5 minutes after midnight every day
#
#  5 0 * * *      $ HOME/bin/daily.job >> $HOME/tmp/out  2>&1
#
# 4. Schedule a job at a specific time on on the first of every month
#
#  15 14 1 * * *     $ HOME/bin/monthly
#
# 5. Schedule a job at a specific time only on weekdays (exclude Saturday and Sunday)
#
#  0 22 * * 1-5  $ HOME/bin/weekday.job >> $HOME/tmp/out  2>&1
#
# 6. Scheduling multiple jobs in a single cron job
#
#  0 12 * * * /var/tmp/script01.sh; /var/tmp/script02.sh

# %% [markdown]
# ### 10.Why set is the fastest data stracture?

# %% [markdown]
# 1-Sets are implemented using hash tables. Whenever you add an object to a set, the position within the memory of the set object is determined using the hash of the object to be added. When testing for membership, all that needs to be done is basically to look if the object is at the position determined by its hash, so the speed of this operation does not depend on the size of the set. For lists, in contrast, the whole list needs to be searched, which will become slower as the list grows.
#
# 2-Sets follow the Binary search tree implementation in searching.
#
# 3-The values in a set are unindexed.
